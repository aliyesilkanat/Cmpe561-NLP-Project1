# %%
import sys
symbols=set()

with open(sys.argv[1]) as f:
    lines=f.readlines()
    for line in lines:
        l=line.split('\t')
        if len(l) ==4:
            print(l)
            symbols.add(l[2])
            symbols.add(l[3].rstrip())
symbols.discard('<eps>')
symbols.discard('<s>')
symbols.discard('</s>')
symbols.discard('<unk>')
ls=list(symbols)
ls=['<eps>','<s>','</s>','<unk>']+ls
for i in range(len(ls)):
    print(str(ls[i])+ "\t"+ str(i))
# Out:
# ['0', '1', '<s>', '<s>\n']
# ['1', '0', '<eps>', '<eps>\n']
# ['0', '2', '</s>', '</s>\n']
# ['2', '0', '<eps>', '<eps>\n']
# ['0', '3', '<unk>', '<unk>\n']
# ['3', '0', '<eps>', '<eps>\n']
# ['0', '4', 'a', 'a\n']
# ['4', '5', 'c', 'c\n']
# ['5', '6', 't', 't\n']
# ['6', '7', '+N+SG', '<eps>\n']
# ['7', '0', '<eps>', '#\n']
# ['6', '8', '+N+PL', '^s\n']
# ['8', '0', '<eps>', '#\n']
# ['4', '9', 'i', 'i\n']
# ['9', '10', 'm', 'm\n']
# ['10', '11', '+N+SG', '<eps>\n']
# ['11', '0', '<eps>', '#\n']
# ['10', '12', '+N+PL', '^s\n']
# ['12', '0', '<eps>', '#\n']
# ['4', '13', 'n', 'n\n']
# ['13', '14', 's', 's\n']
# ['14', '15', 'w', 'w\n']
# ['15', '16', 'e', 'e\n']
# ['16', '17', 'r', 'r\n']
# ['17', '18', '+N+SG', '<eps>\n']
# ['18', '0', '<eps>', '#\n']
# ['17', '19', '+N+PL', '^s\n']
# ['19', '0', '<eps>', '#\n']
# ['4', '20', 'r', 'r\n']
# ['20', '21', 't', 't\n']
# ['21', '22', '+N+SG', '<eps>\n']
# ['22', '0', '<eps>', '#\n']
# ['21', '23', '+N+PL', '^s\n']
# ...

# %%
ls
# Out:
# ['<eps>', '<s>', '</s>', '<unk>']

# %%
symbols
# Out:
# set()

# %%
list(symbols)
# Out:
# []
